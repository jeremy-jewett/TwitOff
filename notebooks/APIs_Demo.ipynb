# %%
# !pip install tweepy
import tweepy

# %%
TWITTER_CONSUMER_API_KEY = 'fJ2pCtnVWNtCEfId4NO7usnx2'
TWITTER_CONSUMER_API_SECRET = 'mYD9O6NXnIpSfoAp6ep7Kp9DQvj29bUDXxNKvOuWaZulbQBPMS'
TWITTER_ACCESS_TOKEN ='1308577866599280640-efB8hpeYznBocikLR9kGASQ1ebPTCC'
TWITTER_ACCESS_TOKEN_SECRET = 'DrJLzFfDIldovCl5f3tS74xa7ZDhmkTpSbOdyUyGxIVgq'

# %%
TWITTER_AUTH = tweepy.OAuthHandler(TWITTER_CONSUMER_API_KEY, TWITTER_CONSUMER_API_SECRET)
TWITTER_AUTH.set_access_token(TWITTER_ACCESS_TOKEN, TWITTER_ACCESS_TOKEN_SECRET)
TWITTER = tweepy.API(TWITTER_AUTH)

# %%
# Showing all that the twitter can do

dir(TWITTER)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_list_members',
#  '_lookup_friendships',
#  '_pack_image',
#  '_remove_list_members',
#  '_send_direct_message',
#  'add_list_member',
#  'add_list_members',
#  'api_root',
#  'auth',
#  'blocks',
#  'blocks_ids',
#  'cache',
#  'compression',
#  'configuration',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'destroy_block',
#  'destroy_direct_message',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
# ...

# %%
# Let's see it get some tweets:

twitter_user = TWITTER.get_user('JimNorton')
twitter_user
# Out:
# User(_api=<tweepy.api.API object at 0x000001F458FF90D0>, _json={'id': 19208457, 'id_str': '19208457', 'name': 'Jim Norton', 'screen_name': 'JimNorton', 'location': "John Wayne Gacy's basement.", 'profile_location': None, 'description': 'THE DEGENERATES SEASON 2 now streaming on NETFLIX - TICKETS https://t.co/2fc8gb60o0', 'url': None, 'entities': {'description': {'urls': [{'url': 'https://t.co/2fc8gb60o0', 'expanded_url': 'http://JimNorton.com/tour', 'display_url': 'JimNorton.com/tour', 'indices': [60, 83]}]}}, 'protected': False, 'followers_count': 511826, 'friends_count': 192, 'listed_count': 5950, 'created_at': 'Mon Jan 19 23:27:44 +0000 2009', 'favourites_count': 6740, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 22618, 'lang': None, 'status': {'created_at': 'Mon Oct 05 00:09:03 +0000 2020', 'id': 1312907616671207427, 'id_str': '1312907616671207427', 'text': 'RT @jackomazza: @JimNorton @ChipChipperson https://t.co/UxKErKtKXz', 't
# ...

# %%
twitter_user.id
# Out:
# 19208457

# %%
jim_tweets = twitter_user.timeline()
jim_tweets
# Out:
# [Status(_api=<tweepy.api.API object at 0x000001F458FF90D0>, _json={'created_at': 'Mon Oct 05 00:09:03 +0000 2020', 'id': 1312907616671207427, 'id_str': '1312907616671207427', 'text': 'RT @jackomazza: @JimNorton @ChipChipperson https://t.co/UxKErKtKXz', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'jackomazza', 'name': 'Andrew', 'id': 38488615, 'id_str': '38488615', 'indices': [3, 14]}, {'screen_name': 'JimNorton', 'name': 'Jim Norton', 'id': 19208457, 'id_str': '19208457', 'indices': [16, 26]}, {'screen_name': 'ChipChipperson', 'name': 'The Chip Chipperson Show', 'id': 104004124, 'id_str': '104004124', 'indices': [27, 42]}], 'urls': [], 'media': [{'id': 1312553343093477378, 'id_str': '1312553343093477378', 'indices': [43, 66], 'media_url': 'http://pbs.twimg.com/ext_tw_video_thumb/1312553343093477378/pu/img/sjvX5f-myV7KWR9A.jpg', 'media_url_https': 'https://pbs.twimg.com/ext_tw_video_thumb/1312553343093477378/pu/img/sjvX5f-myV7KWR9A
# ...

# %%
jim_tweets[0].text
# Out:
# 'RT @jackomazza: @JimNorton @ChipChipperson https://t.co/UxKErKtKXz'

# %%
len(jim_tweets)
# Out:
# 20

# %%
jim_tweets = twitter_user.timeline(count=200,
                                    exclude_replies=True,
                                    include_rts=False,
                                    # max_id='1303802636827799555',
                                    tweet_mode='extended')

len(jim_tweets)
# Out:
# 162

# %%
# !pip install spacy
import spacy

# %%
import spacy
# !pip install en_core_web_md
import en_core_web_md

nlp = en_core_web_md.load()
nlp.to_disk('spacy_md_model')
# Out:
# ERROR: Could not find a version that satisfies the requirement en_core_web_md (from versions: none)
# ERROR: No matching distribution found for en_core_web_md
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-8d559553aaa6> in <module>
#       1 import spacy
#       2 get_ipython().system('pip install en_core_web_md')
# ----> 3 import en_core_web_md
#       4
#       5 nlp = en_core_web_md.load()
#
# ModuleNotFoundError: No module named 'en_core_web_md'
